# %% [markdown]
# # Etapa 3

# %% [markdown]
# ## Librerías y dataset

# %%
import streamlit
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Visualización del dataset

# %%
#Primeros 10 registros del dataset
df_muestra = pd.read_csv('logs_modelos_tabasco.csv')
display(df_muestra.head(10))
# Out:
#    Mujeres de 12-49  Poblacion Total  Poblacion de 0 a 5  Personas c/religion  \
# 0          3.489600         3.367296            0.000000             3.367296
# 1          3.663562         4.709530            1.609438             4.584967
# 2          3.489600         3.713572            0.000000             4.383570
# 3          3.489600         3.970292            1.386294             3.912023
# 4          3.637586         4.795791            1.609438             4.727388
# 5          3.218876         4.477337            2.079442             4.343805
# 6          2.484907         3.806662            1.386294             3.610918
# 7          1.386294         2.639057            0.000000             4.383570
# 8          3.489600         4.304065            1.609438             4.110874
# 9          3.218876         4.406719            1.945910             4.356709
#
#    Personas Casadas  Personas s/religion  Personas Ocupadas  \
# ...

# %%
#Forma del dataset
display(df_muestra.shape)
# Out:
# (11278, 9)

# %%
DeepnoteChart(df_muestra, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#C8338A","tooltip":true},"encoding":{"x":{"bin":true,"axis":{"title":"Número de infantes"},"sort":null,"type":"quantitative","field":"Poblacion de 0 a 5"},"y":{"axis":{"title":"Frecuencia"},"sort":null,"type":"quantitative","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"count","formatType":"numberFormatFromNumberType"}}}]}],"title":"Histograma datos balanceados","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"aditionalTypeInfo":{"histogramLayerIndexes":[0]},"tooltipDefaultMode":true}}""")

# %% [markdown]
# ## Preparar dataset para los modelos

# %%
df = df_muestra
X = df.drop('Poblacion de 0 a 5', axis=1)  # Vector de características
y = df['Poblacion de 0 a 5']               # Variable objetivo

# %% [markdown]
# ## Modelo Árboles de Decisión

# %%
#Modelo
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=23)
model = DecisionTreeRegressor(max_depth = 12, min_samples_split = 7) #Hiperparámetros
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=12, min_samples_split=7)

# %%
#Evaluar modelo
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test,y_pred)
Resultados=pd.DataFrame([y_pred,y_test]).T
Resultados.columns=['y_test','y_pred']
display(Resultados)
print("Error medio cuadrado: ", mse)
print("R^2: ", r2)
# Out:
#         y_test    y_pred
# 0     0.000000  0.000000
# 1     1.441939  1.609438
# 2     0.000000  0.000000
# 3     0.160944  0.000000
# 4     0.000000  0.000000
# ...        ...       ...
# 2589  0.095395  0.000000
# 2590  0.030137  0.000000
# 2591  0.000000  0.000000
# 2592  1.038027  1.386294
# 2593  1.978758  2.197225
#
# [2594 rows x 2 columns]
# Error medio cuadrado:  0.2862866723462117
# R^2:  0.7392483972332495

# %% [markdown]
# ## Modelo Random Forest

# %%
# Modelo
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=23)
model = RandomForestRegressor(n_estimators = 50, max_depth = 7) #Hiperparámetros
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=7, n_estimators=50)

# %%
#Evaluar modelo
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test,y_pred)
Resultados=pd.DataFrame([y_pred,y_test]).T
Resultados.columns=['y_test','y_pred']
display(Resultados)
print("Error medio cuadrado: ", mse)
print("R^2: ", r2)
# Out:
#         y_test    y_pred
# 0     0.000000  0.000000
# 1     1.529113  1.609438
# 2     0.000653  0.000000
# 3     0.627541  0.000000
# 4     0.000000  0.000000
# ...        ...       ...
# 2589  0.120831  0.000000
# 2590  0.232918  0.000000
# 2591  0.000000  0.000000
# 2592  0.758672  1.386294
# 2593  1.988767  2.197225
#
# [2594 rows x 2 columns]
# Error medio cuadrado:  0.1881385283672644
# R^2:  0.8286423101295617

# %% [markdown]
# ## Regresión Lineal

# %%
#Modelo
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.23,random_state=23)
reg=LinearRegression() #No tiene hiperparámetros considerables para cambiar
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Evaluar modelo
y_pred = reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test,y_pred)
Resultados=pd.DataFrame([y_pred,y_test]).T
Resultados.columns=['y_test','y_pred']
display(Resultados)
print("Error medio cuadrado: ", mse)
print("R^2: ", r2)
# Out:
#         y_test    y_pred
# 0    -0.334681  0.000000
# 1     1.481082  1.609438
# 2     0.822266  0.000000
# 3     0.699786  0.000000
# 4    -0.334681  0.000000
# ...        ...       ...
# 2589  0.638350  0.000000
# 2590  1.108812  0.000000
# 2591 -0.334681  0.000000
# 2592  0.880396  1.386294
# 2593  1.571609  2.197225
#
# [2594 rows x 2 columns]
# Error medio cuadrado:  0.3032828695108355
# R^2:  0.7237681598359043

# %% [markdown]
# ## Ridge

# %%
#Modelo
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.23,random_state=23)
reg_ridge=Ridge() #No hay hiperparámetros considerables para cambiar
reg_ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
#Evaluar modelo
y_pred = reg_ridge.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test,y_pred)
Resultados=pd.DataFrame([y_pred,y_test]).T
Resultados.columns=['y_test','y_pred']
display(Resultados)
print("Error medio cuadrado: ", mse)
print("R^2: ", r2)
# Out:
#         y_test    y_pred
# 0    -0.334778  0.000000
# 1     1.480971  1.609438
# 2     0.822144  0.000000
# 3     0.700036  0.000000
# 4    -0.334778  0.000000
# ...        ...       ...
# 2589  0.638497  0.000000
# 2590  1.108782  0.000000
# 2591 -0.334778  0.000000
# 2592  0.880484  1.386294
# 2593  1.571568  2.197225
#
# [2594 rows x 2 columns]
# Error medio cuadrado:  0.30328463326972344
# R^2:  0.723766553393826

# %% [markdown]
# ## Lasso

# %%
#Modelo
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.23,random_state=23)
reg_lasso=Lasso(alpha=0.23) #El único hiperparámetro considerable es alpha
reg_lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.23)

# %%
#Evaluar modelo
y_pred = reg_lasso.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test,y_pred)
Resultados=pd.DataFrame([y_pred,y_test]).T
Resultados.columns=['y_test','y_pred']
display(Resultados)
print("Error medio cuadrado: ", mse)
print("R^2: ", r2)
# Out:
#         y_test    y_pred
# 0    -0.214051  0.000000
# 1     1.519655  1.609438
# 2     0.818132  0.000000
# 3     1.132730  0.000000
# 4    -0.214051  0.000000
# ...        ...       ...
# 2589  1.036189  0.000000
# 2590  1.015790  0.000000
# 2591 -0.214051  0.000000
# 2592  1.259809  1.386294
# 2593  1.655503  2.197225
#
# [2594 rows x 2 columns]
# Error medio cuadrado:  0.3890320580947965
# R^2:  0.6456672892086586

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c0848c89-aa3f-4842-a14c-1735a6491904' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
